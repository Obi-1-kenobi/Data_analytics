# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress


# Import API key
from api_keys import weather_api_key

# pip install citipy was done for this
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %%
#Lists and counters
city_list = []
cloud_list = []
country_list = []
date_list = []
humidity_list = []
lats_list = []
lngs_list = []
temp_max_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#API
base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="

#For loop  city names with city_list 
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_list.append(response["name"])
        cloud_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lats_list.append(response["coord"]["lat"])
        lngs_list.append(response["coord"]["lon"])
        temp_max_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
        
        else:
            index_counter = index_counter + 1
        
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}")
        
    except(KeyError, IndexError):
        print("City not found. Skipping...")
#print to let the user know its done???        
#print("Done")
# Out:
# Processing Record 1 of Set 1 : camocim
# Processing Record 2 of Set 1 : iqaluit
# City not found. Skipping...
# Processing Record 3 of Set 1 : tuatapere
# Processing Record 4 of Set 1 : port alfred
# Processing Record 5 of Set 1 : san cristobal
# Processing Record 6 of Set 1 : jamestown
# Processing Record 7 of Set 1 : cape town
# Processing Record 8 of Set 1 : mogadishu
# Processing Record 9 of Set 1 : galle
# City not found. Skipping...
# Processing Record 10 of Set 1 : busselton
# Processing Record 11 of Set 1 : mataura
# Processing Record 12 of Set 1 : nhulunbuy
# Processing Record 13 of Set 1 : bilibino
# Processing Record 14 of Set 1 : ushuaia
# Processing Record 15 of Set 1 : rikitea
# Processing Record 16 of Set 1 : yerbogachen
# Processing Record 17 of Set 1 : arlit
# Processing Record 18 of Set 1 : sitka
# Processing Record 19 of Set 1 : bacabal
# Processing Record 20 of Set 1 : butaritari
# Processing Record 21 of Set 1 : nanortalik
# Processing Record 22 of Set 1 : tabory
# Processing Record 23 of Set 1 : yatou
# Processing Record 24 of Set 1 : namatanai
# Processing Record 25 of Set 1 : avera
# Processing Record 26 of Set 1 : longyearbyen
# Processing Record 27 of Set 1 : kapaa
# Processing Record 28 of Set 1 : moyale
# Processing Record 29 of Set 1 : barrow
# Processing Record 30 of Set 1 : xining
# City not found. Skipping...
# Processing Record 31 of Set 1 : talnakh
# Processing Record 32 of Set 1 : grindavik
# Processing Record 33 of Set 1 : bredasdorp
# Processing Record 34 of Set 1 : imeni vorovskogo
# Processing Record 35 of Set 1 : fort nelson
# City not found. Skipping...
# Processing Record 36 of Set 1 : nikolskoye
# City not found. Skipping...
# Processing Record 37 of Set 1 : samarai
# Processing Record 38 of Set 1 : hobart
# Processing Record 39 of Set 1 : mount gambier
# Processing Record 40 of Set 1 : dikson
# Processing Record 41 of Set 1 : saskylakh
# Processing Record 42 of Set 1 : turayf
# Processing Record 43 of Set 1 : tezu
# City not found. Skipping...
# Processing Record 44 of Set 1 : hermanus
# Processing Record 45 of Set 1 : souillac
# Processing Record 46 of Set 1 : bluff
# Processing Record 47 of Set 1 : punta arenas
# Processing Record 48 of Set 1 : atuona
# Processing Record 49 of Set 1 : maragogi
# Processing Record 50 of Set 1 : kavieng
# Processing Record 0 of Set 2 : khatanga
# Processing Record 1 of Set 2 : tevriz
# Processing Record 2 of Set 2 : vaini
# Processing Record 3 of Set 2 : albany
# Processing Record 4 of Set 2 : east london
# Processing Record 5 of Set 2 : mahebourg
# Processing Record 6 of Set 2 : norman wells
# Processing Record 7 of Set 2 : san patricio
# Processing Record 8 of Set 2 : morondava
# Processing Record 9 of Set 2 : havre-saint-pierre
# City not found. Skipping...
# Processing Record 10 of Set 2 : port macquarie
# Processing Record 11 of Set 2 : presque isle
# Processing Record 12 of Set 2 : gaozhou
# Processing Record 13 of Set 2 : castro
# Processing Record 14 of Set 2 : raudeberg
# Processing Record 15 of Set 2 : cotonou
# Processing Record 16 of Set 2 : saint-philippe
# Processing Record 17 of Set 2 : nisia floresta
# Processing Record 18 of Set 2 : paciran
# Processing Record 19 of Set 2 : florianopolis
# Processing Record 20 of Set 2 : dennis
# Processing Record 21 of Set 2 : amapa
# Processing Record 22 of Set 2 : faridpur
# Processing Record 23 of Set 2 : kodiak
# Processing Record 24 of Set 2 : hambantota
# City not found. Skipping...
# Processing Record 25 of Set 2 : yellowknife
# Processing Record 26 of Set 2 : namibe
# Processing Record 27 of Set 2 : provideniya
# Processing Record 28 of Set 2 : alihe
# Processing Record 29 of Set 2 : rawson
# Processing Record 30 of Set 2 : praia da vitoria
# City not found. Skipping...
# Processing Record 31 of Set 2 : trelew
# Processing Record 32 of Set 2 : okhotsk
# Processing Record 33 of Set 2 : general roca
# Processing Record 34 of Set 2 : lagoa
# Processing Record 35 of Set 2 : carnarvon
# Processing Record 36 of Set 2 : fairbanks
# Processing Record 37 of Set 2 : vila do maio
# Processing Record 38 of Set 2 : torbay
# Processing Record 39 of Set 2 : hasaki
# Processing Record 40 of Set 2 : ahipara
# Processing Record 41 of Set 2 : avarua
# Processing Record 42 of Set 2 : elbasan
# Processing Record 43 of Set 2 : balikpapan
# Processing Record 44 of Set 2 : margate
# Processing Record 45 of Set 2 : langelsheim
# City not found. Skipping...
# Processing Record 46 of Set 2 : diffa
# Processing Record 47 of Set 2 : manoel urbano
# Processing Record 48 of Set 2 : lebu
# Processing Record 49 of Set 2 : kaitangata
# Processing Record 50 of Set 2 : aqtobe
# Processing Record 0 of Set 3 : pevek
# Processing Record 1 of Set 3 : palmer
# Processing Record 2 of Set 3 : muroto
# Processing Record 3 of Set 3 : sept-iles
# Processing Record 4 of Set 3 : los llanos de aridane
# Processing Record 5 of Set 3 : hilo
# Processing Record 6 of Set 3 : saint george
# Processing Record 7 of Set 3 : sabratah
# Processing Record 8 of Set 3 : betong
# Processing Record 9 of Set 3 : hualmay
# Processing Record 10 of Set 3 : puerto ayora
# Processing Record 11 of Set 3 : clyde river
# Processing Record 12 of Set 3 : jimo
# Processing Record 13 of Set 3 : luderitz
# Processing Record 14 of Set 3 : visby
# Processing Record 15 of Set 3 : dwarka
# Processing Record 16 of Set 3 : liverpool
# Processing Record 17 of Set 3 : victoria
# City not found. Skipping...
# Processing Record 18 of Set 3 : nueva loja
# Processing Record 19 of Set 3 : okha
# Processing Record 20 of Set 3 : bolobo
# Processing Record 21 of Set 3 : kununurra
# Processing Record 22 of Set 3 : te anau
# Processing Record 23 of Set 3 : cidreira
# Processing Record 24 of Set 3 : new norfolk
# Processing Record 25 of Set 3 : narsaq
# Processing Record 26 of Set 3 : teguldet
# Processing Record 27 of Set 3 : upernavik
# Processing Record 28 of Set 3 : batagay
# Processing Record 29 of Set 3 : lauda-konigshofen
# City not found. Skipping...
# Processing Record 30 of Set 3 : diamantino
# Processing Record 31 of Set 3 : zeya
# Processing Record 32 of Set 3 : guerrero negro
# Processing Record 33 of Set 3 : gizo
# Processing Record 34 of Set 3 : bethel
# Processing Record 35 of Set 3 : longido
# City not found. Skipping...
# Processing Record 36 of Set 3 : rabo de peixe
# Processing Record 37 of Set 3 : cherskiy
# Processing Record 38 of Set 3 : saint-pierre
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 3 : cayenne
# Processing Record 40 of Set 3 : jumla
# Processing Record 41 of Set 3 : gushikawa
# Processing Record 42 of Set 3 : isangel
# Processing Record 43 of Set 3 : bandarbeyla
# Processing Record 44 of Set 3 : atar
# Processing Record 45 of Set 3 : bairiki
# Processing Record 46 of Set 3 : lumberton
# Processing Record 47 of Set 3 : lam luk ka
# Processing Record 48 of Set 3 : san simon de la laguna
# Processing Record 49 of Set 3 : las vegas
# Processing Record 50 of Set 3 : anchorage
# Processing Record 0 of Set 4 : georgetown
# City not found. Skipping...
# Processing Record 1 of Set 4 : maniitsoq
# Processing Record 2 of Set 4 : vao
# City not found. Skipping...
# Processing Record 3 of Set 4 : saint-joseph
# Processing Record 4 of Set 4 : touros
# Processing Record 5 of Set 4 : calatayud
# Processing Record 6 of Set 4 : timaru
# Processing Record 7 of Set 4 : kalmunai
# Processing Record 8 of Set 4 : mar del plata
# Processing Record 9 of Set 4 : trincomalee
# Processing Record 10 of Set 4 : panacan
# Processing Record 11 of Set 4 : lakes entrance
# Processing Record 12 of Set 4 : karagay
# Processing Record 13 of Set 4 : tuktoyaktuk
# Processing Record 14 of Set 4 : moron
# Processing Record 15 of Set 4 : katsuura
# Processing Record 16 of Set 4 : smolenka
# Processing Record 17 of Set 4 : townsville
# Processing Record 18 of Set 4 : hithadhoo
# Processing Record 19 of Set 4 : qaanaaq
# Processing Record 20 of Set 4 : alofi
# Processing Record 21 of Set 4 : vryburg
# Processing Record 22 of Set 4 : kushmurun
# Processing Record 23 of Set 4 : ostrovnoy
# Processing Record 24 of Set 4 : tecoanapa
# Processing Record 25 of Set 4 : kwinana
# Processing Record 26 of Set 4 : la ciotat
# Processing Record 27 of Set 4 : vardo
# Processing Record 28 of Set 4 : ribeira grande
# Processing Record 29 of Set 4 : tiksi
# City not found. Skipping...
# Processing Record 30 of Set 4 : porbandar
# Processing Record 31 of Set 4 : daru
# Processing Record 32 of Set 4 : makakilo city
# Processing Record 33 of Set 4 : bilma
# Processing Record 34 of Set 4 : srednekolymsk
# Processing Record 35 of Set 4 : bara
# Processing Record 36 of Set 4 : antsirabe
# Processing Record 37 of Set 4 : pathein
# Processing Record 38 of Set 4 : lorengau
# City not found. Skipping...
# Processing Record 39 of Set 4 : fare
# Processing Record 40 of Set 4 : dingle
# Processing Record 41 of Set 4 : san carlos de bariloche
# Processing Record 42 of Set 4 : thompson
# Processing Record 43 of Set 4 : port blair
# Processing Record 44 of Set 4 : fulton
# Processing Record 45 of Set 4 : quatre cocos
# Processing Record 46 of Set 4 : lavrentiya
# Processing Record 47 of Set 4 : kaputa
# Processing Record 48 of Set 4 : kopong
# City not found. Skipping...
# Processing Record 49 of Set 4 : gold coast
# City not found. Skipping...
# Processing Record 50 of Set 4 : klaksvik
# City not found. Skipping...
# Processing Record 0 of Set 5 : jamsa
# Processing Record 1 of Set 5 : lipari
# City not found. Skipping...
# Processing Record 2 of Set 5 : mecca
# Processing Record 3 of Set 5 : zhezkazgan
# Processing Record 4 of Set 5 : hongjiang
# Processing Record 5 of Set 5 : somerset east
# Processing Record 6 of Set 5 : chapada dos guimaraes
# Processing Record 7 of Set 5 : binga
# Processing Record 8 of Set 5 : tucuman
# Processing Record 9 of Set 5 : ust-omchug
# Processing Record 10 of Set 5 : bosaso
# Processing Record 11 of Set 5 : chokurdakh
# Processing Record 12 of Set 5 : leningradskiy
# Processing Record 13 of Set 5 : vallenar
# Processing Record 14 of Set 5 : manyana
# Processing Record 15 of Set 5 : yulara
# Processing Record 16 of Set 5 : turukhansk
# Processing Record 17 of Set 5 : tura
# Processing Record 18 of Set 5 : nyimba
# Processing Record 19 of Set 5 : petapa
# Processing Record 20 of Set 5 : vredendal
# Processing Record 21 of Set 5 : raga
# Processing Record 22 of Set 5 : ust-nera
# City not found. Skipping...
# Processing Record 23 of Set 5 : promissao
# Processing Record 24 of Set 5 : yar-sale
# Processing Record 25 of Set 5 : koygorodok
# City not found. Skipping...
# Processing Record 26 of Set 5 : jiazi
# Processing Record 27 of Set 5 : oussouye
# Processing Record 28 of Set 5 : fortuna
# Processing Record 29 of Set 5 : arraial do cabo
# City not found. Skipping...
# Processing Record 30 of Set 5 : chuy
# City not found. Skipping...
# Processing Record 31 of Set 5 : oistins
# City not found. Skipping...
# Processing Record 32 of Set 5 : aklavik
# Processing Record 33 of Set 5 : alyangula
# Processing Record 34 of Set 5 : salvador
# City not found. Skipping...
# Processing Record 35 of Set 5 : neka
# Processing Record 36 of Set 5 : brighton
# Processing Record 37 of Set 5 : broken hill
# Processing Record 38 of Set 5 : sur
# Processing Record 39 of Set 5 : severo-kurilsk
# Processing Record 40 of Set 5 : cabo san lucas
# Processing Record 41 of Set 5 : lerwick
# Processing Record 42 of Set 5 : ponta do sol
# Processing Record 43 of Set 5 : kargat
# Processing Record 44 of Set 5 : lesnyye polyany
# Processing Record 45 of Set 5 : sungai besar
# Processing Record 46 of Set 5 : peleduy
# Processing Record 47 of Set 5 : katherine
# Processing Record 48 of Set 5 : omboue
# Processing Record 49 of Set 5 : matadi
# Processing Record 50 of Set 5 : nyurba
# Processing Record 0 of Set 6 : tomatlan
# Processing Record 1 of Set 6 : ucluelet
# Processing Record 2 of Set 6 : lapua
# Processing Record 3 of Set 6 : airai
# Processing Record 4 of Set 6 : east stroudsburg
# Processing Record 5 of Set 6 : ipanema
# Processing Record 6 of Set 6 : esperance
# Processing Record 7 of Set 6 : port hardy
# Processing Record 8 of Set 6 : sisimiut
# Processing Record 9 of Set 6 : sao joao da barra
# Processing Record 10 of Set 6 : nata
# Processing Record 11 of Set 6 : bolu
# Processing Record 12 of Set 6 : sao filipe
# Processing Record 13 of Set 6 : verkhnevilyuysk
# Processing Record 14 of Set 6 : bathsheba
# Processing Record 15 of Set 6 : machinga
# Processing Record 16 of Set 6 : san joaquin
# Processing Record 17 of Set 6 : tasiilaq
# Processing Record 18 of Set 6 : antalaha
# Processing Record 19 of Set 6 : peto
# Processing Record 20 of Set 6 : port elizabeth
# Processing Record 21 of Set 6 : fairmont
# City not found. Skipping...
# Processing Record 22 of Set 6 : bam
# Processing Record 23 of Set 6 : saldanha
# Processing Record 24 of Set 6 : coolum beach
# Processing Record 25 of Set 6 : nuevo progreso
# Processing Record 26 of Set 6 : kamra
# Processing Record 27 of Set 6 : donskoye
# Processing Record 28 of Set 6 : perelyub
# Processing Record 29 of Set 6 : pangnirtung
# Processing Record 30 of Set 6 : mayor pablo lagerenza
# Processing Record 31 of Set 6 : tual
# Processing Record 32 of Set 6 : prince rupert
# Processing Record 33 of Set 6 : buraydah
# Processing Record 34 of Set 6 : padang
# Processing Record 35 of Set 6 : nakamura
# Processing Record 36 of Set 6 : kahului
# Processing Record 37 of Set 6 : dumas
# Processing Record 38 of Set 6 : korla
# Processing Record 39 of Set 6 : bukama
# Processing Record 40 of Set 6 : beringovskiy
# Processing Record 41 of Set 6 : tocopilla
# Processing Record 42 of Set 6 : khani
# Processing Record 43 of Set 6 : cozumel
# Processing Record 44 of Set 6 : athabasca
# Processing Record 45 of Set 6 : peniche
# City not found. Skipping...
# Processing Record 46 of Set 6 : narasannapeta
# Processing Record 47 of Set 6 : husavik
# Processing Record 48 of Set 6 : schruns
# Processing Record 49 of Set 6 : faanui
# Processing Record 50 of Set 6 : tessalit
# Processing Record 0 of Set 7 : anadyr
# Processing Record 1 of Set 7 : kailua
# Processing Record 2 of Set 7 : qiongshan
# Processing Record 3 of Set 7 : hervey bay
# Processing Record 4 of Set 7 : cheney
# Processing Record 5 of Set 7 : dawlatabad
# Processing Record 6 of Set 7 : gat
# Processing Record 7 of Set 7 : envira
# Processing Record 8 of Set 7 : rio grande
# Processing Record 9 of Set 7 : takoradi
# Processing Record 10 of Set 7 : roald
# Processing Record 11 of Set 7 : portland
# Processing Record 12 of Set 7 : mantua
# Processing Record 13 of Set 7 : pringsewu
# Processing Record 14 of Set 7 : hamilton
# Processing Record 15 of Set 7 : billings
# Processing Record 16 of Set 7 : zambezi
# Processing Record 17 of Set 7 : naze
# Processing Record 18 of Set 7 : chernyshevskiy
# Processing Record 19 of Set 7 : mapastepec
# Processing Record 20 of Set 7 : moundsville
# Processing Record 21 of Set 7 : rumphi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 7 : mildura
# Processing Record 23 of Set 7 : teya
# Processing Record 24 of Set 7 : ende
# City not found. Skipping...
# Processing Record 25 of Set 7 : jiaohe
# Processing Record 26 of Set 7 : ancud
# Processing Record 27 of Set 7 : jerome
# Processing Record 28 of Set 7 : asau
# Processing Record 29 of Set 7 : salgueiro
# City not found. Skipping...
# Processing Record 30 of Set 7 : constitucion
# Processing Record 31 of Set 7 : tapes
# Processing Record 32 of Set 7 : haines junction
# Processing Record 33 of Set 7 : kupang
# Processing Record 34 of Set 7 : kieta
# Processing Record 35 of Set 7 : neubrandenburg
# Processing Record 36 of Set 7 : impfondo
# Processing Record 37 of Set 7 : mitu
# Processing Record 38 of Set 7 : mitsamiouli
# Processing Record 39 of Set 7 : ahuimanu
# Processing Record 40 of Set 7 : ures
# Processing Record 41 of Set 7 : richmond hill
# Processing Record 42 of Set 7 : kavaratti
# Processing Record 43 of Set 7 : kabinda
# Processing Record 44 of Set 7 : nome
# Processing Record 45 of Set 7 : goderich
# Processing Record 46 of Set 7 : iranshahr
# Processing Record 47 of Set 7 : belaguntha
# Processing Record 48 of Set 7 : lufilufi
# Processing Record 49 of Set 7 : aborlan
# Processing Record 50 of Set 7 : cooma
# Processing Record 0 of Set 8 : fukue
# Processing Record 1 of Set 8 : cotacachi
# Processing Record 2 of Set 8 : wagar
# Processing Record 3 of Set 8 : santa cruz
# Processing Record 4 of Set 8 : lokosovo
# Processing Record 5 of Set 8 : thinadhoo
# Processing Record 6 of Set 8 : mandera
# Processing Record 7 of Set 8 : bambous virieux
# Processing Record 8 of Set 8 : manokwari
# Processing Record 9 of Set 8 : ust-kuyga
# Processing Record 10 of Set 8 : lethem
# Processing Record 11 of Set 8 : ingham
# Processing Record 12 of Set 8 : segezha
# Processing Record 13 of Set 8 : olafsvik
# Processing Record 14 of Set 8 : kutulik
# Processing Record 15 of Set 8 : flinders
# Processing Record 16 of Set 8 : westport
# Processing Record 17 of Set 8 : grand-santi
# Processing Record 18 of Set 8 : gorom-gorom
# Processing Record 19 of Set 8 : scarborough
# Processing Record 20 of Set 8 : wilhelmshaven
# City not found. Skipping...
# Processing Record 21 of Set 8 : labuan
# Processing Record 22 of Set 8 : massaguet
# Processing Record 23 of Set 8 : shaoxing
# Processing Record 24 of Set 8 : kamenka
# City not found. Skipping...
# Processing Record 25 of Set 8 : vestmanna
# Processing Record 26 of Set 8 : petrolina
# Processing Record 27 of Set 8 : ayr
# Processing Record 28 of Set 8 : svetlogorsk
# Processing Record 29 of Set 8 : vila franca do campo
# Processing Record 30 of Set 8 : shamary
# Processing Record 31 of Set 8 : shache
# Processing Record 32 of Set 8 : coracora
# Processing Record 33 of Set 8 : grand-lahou
# City not found. Skipping...
# Processing Record 34 of Set 8 : dauphin
# Processing Record 35 of Set 8 : umm kaddadah
# Processing Record 36 of Set 8 : anzio
# Processing Record 37 of Set 8 : henties bay
# Processing Record 38 of Set 8 : murray bridge
# Processing Record 39 of Set 8 : adre
# Processing Record 40 of Set 8 : mandalgovi
# Processing Record 41 of Set 8 : huarmey
# Processing Record 42 of Set 8 : puerto quijarro
# Processing Record 43 of Set 8 : soyo
# Processing Record 44 of Set 8 : mackenzie
# Processing Record 45 of Set 8 : gardone val trompia
# City not found. Skipping...
# Processing Record 46 of Set 8 : oksfjord
# City not found. Skipping...
# Processing Record 47 of Set 8 : nouadhibou
# Processing Record 48 of Set 8 : seydi
# Processing Record 49 of Set 8 : oranjemund
# Processing Record 50 of Set 8 : portree
# Processing Record 0 of Set 9 : north bend
# Processing Record 1 of Set 9 : hobyo
# Processing Record 2 of Set 9 : dekar
# Processing Record 3 of Set 9 : ambilobe
# Processing Record 4 of Set 9 : saint-francois
# Processing Record 5 of Set 9 : moundou
# Processing Record 6 of Set 9 : upata
# Processing Record 7 of Set 9 : kathu
# Processing Record 8 of Set 9 : pushkino
# Processing Record 9 of Set 9 : garhi khairo
# Processing Record 10 of Set 9 : horadiz
# Processing Record 11 of Set 9 : urengoy
# Processing Record 12 of Set 9 : chiredzi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 9 : luena
# Processing Record 14 of Set 9 : coquimbo
# Processing Record 15 of Set 9 : leninskoye
# Processing Record 16 of Set 9 : verkh-usugli
# Processing Record 17 of Set 9 : kisangani
# Processing Record 18 of Set 9 : zwedru
# Processing Record 19 of Set 9 : broome
# Processing Record 20 of Set 9 : gravdal
# Processing Record 21 of Set 9 : egvekinot
# Processing Record 22 of Set 9 : beaufort
# City not found. Skipping...
# Processing Record 23 of Set 9 : ust-kulom
# Processing Record 24 of Set 9 : lagos
# Processing Record 25 of Set 9 : durgapur
# Processing Record 26 of Set 9 : nuuk
# Processing Record 27 of Set 9 : grado
# Processing Record 28 of Set 9 : karonga
# Processing Record 29 of Set 9 : half moon bay
# City not found. Skipping...
# Processing Record 30 of Set 9 : sorland
# Processing Record 31 of Set 9 : gritsovskiy
# Processing Record 32 of Set 9 : soe
# Processing Record 33 of Set 9 : palafrugell
# Processing Record 34 of Set 9 : berehomet
# Processing Record 35 of Set 9 : bud
# Processing Record 36 of Set 9 : chapais
# Processing Record 37 of Set 9 : bengkulu
# Processing Record 38 of Set 9 : gazanjyk
# Processing Record 39 of Set 9 : port-gentil
# Processing Record 40 of Set 9 : hamada
# Processing Record 41 of Set 9 : richards bay
# City not found. Skipping...
# Processing Record 42 of Set 9 : waingapu
# Processing Record 43 of Set 9 : tateyama
# Processing Record 44 of Set 9 : biltine
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 9 : yenagoa
# Processing Record 46 of Set 9 : san ramon
# Processing Record 47 of Set 9 : basoko
# City not found. Skipping...
# Processing Record 48 of Set 9 : portel
# Processing Record 49 of Set 9 : changde
# Processing Record 50 of Set 9 : dongsheng
# Processing Record 0 of Set 10 : geraldton
# Processing Record 1 of Set 10 : gaspe
# Processing Record 2 of Set 10 : vaitape
# Processing Record 3 of Set 10 : sovetskiy
# Processing Record 4 of Set 10 : kem
# Processing Record 5 of Set 10 : mount isa
# Processing Record 6 of Set 10 : livingstonia
# Processing Record 7 of Set 10 : cianorte
# Processing Record 8 of Set 10 : uturoa
# Processing Record 9 of Set 10 : chunoyar
# Processing Record 10 of Set 10 : eureka
# Processing Record 11 of Set 10 : sharjah
# Processing Record 12 of Set 10 : obidos
# Processing Record 13 of Set 10 : nizwa
# Processing Record 14 of Set 10 : biloela
# Processing Record 15 of Set 10 : langsa
# Processing Record 16 of Set 10 : baykit
# Processing Record 17 of Set 10 : kurilsk
# Processing Record 18 of Set 10 : mehamn
# Processing Record 19 of Set 10 : iwaki
# Processing Record 20 of Set 10 : rustenburg
# Processing Record 21 of Set 10 : imeni poliny osipenko
# Processing Record 22 of Set 10 : omsukchan
# Processing Record 23 of Set 10 : pechenga
# Processing Record 24 of Set 10 : teknaf
# Processing Record 25 of Set 10 : iowa city
# Processing Record 26 of Set 10 : beloha
# City not found. Skipping...
# Processing Record 27 of Set 10 : hami
# Processing Record 28 of Set 10 : dana point
# Processing Record 29 of Set 10 : ballina
# Processing Record 30 of Set 10 : atambua
# Processing Record 31 of Set 10 : sabang
# Processing Record 32 of Set 10 : alushta
# Processing Record 33 of Set 10 : bereda
# Processing Record 34 of Set 10 : port keats
# Processing Record 35 of Set 10 : mangai
# Processing Record 36 of Set 10 : ippy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 10 : meybod
# Processing Record 38 of Set 10 : luwuk
# Processing Record 39 of Set 10 : roma
# Processing Record 40 of Set 10 : batemans bay
# Processing Record 41 of Set 10 : ulaanbaatar
# City not found. Skipping...
# Processing Record 42 of Set 10 : qena
# Processing Record 43 of Set 10 : harper
# Processing Record 44 of Set 10 : mweka
# Processing Record 45 of Set 10 : kortkeros
# Processing Record 46 of Set 10 : jinchang
# Processing Record 47 of Set 10 : prado
# Processing Record 48 of Set 10 : banjar
# Processing Record 49 of Set 10 : flin flon
# Processing Record 50 of Set 10 : riyadh
# Processing Record 0 of Set 11 : bonavista
# Processing Record 1 of Set 11 : camacha
# City not found. Skipping...
# Processing Record 2 of Set 11 : puerto escondido
# Processing Record 3 of Set 11 : pisco
# Processing Record 4 of Set 11 : urzhum
# Processing Record 5 of Set 11 : pacific grove
# Processing Record 6 of Set 11 : brae
# Processing Record 7 of Set 11 : pyapon
# City not found. Skipping...
# Processing Record 8 of Set 11 : barabai
# Processing Record 9 of Set 11 : kaifeng
# City not found. Skipping...
# Processing Record 10 of Set 11 : mirnyy
# Processing Record 11 of Set 11 : pella
# Processing Record 12 of Set 11 : yueyang
# Processing Record 13 of Set 11 : thyolo
# Processing Record 14 of Set 11 : antsohihy
# Processing Record 15 of Set 11 : vilyuysk
# Processing Record 16 of Set 11 : sinnamary
# Processing Record 17 of Set 11 : yamada
# Processing Record 18 of Set 11 : colombo
# City not found. Skipping...
# Processing Record 19 of Set 11 : skjervoy
# Processing Record 20 of Set 11 : chara
# Processing Record 21 of Set 11 : ornskoldsvik
# Processing Record 22 of Set 11 : kologriv
# Processing Record 23 of Set 11 : radhanpur
# Processing Record 24 of Set 11 : morro bay
# Processing Record 25 of Set 11 : seoul
# Processing Record 26 of Set 11 : bagdarin
# Processing Record 27 of Set 11 : conceicao do araguaia
# Processing Record 28 of Set 11 : utete
# Processing Record 29 of Set 11 : fuyang
# Processing Record 30 of Set 11 : kushiro
# Processing Record 31 of Set 11 : taksimo
# Processing Record 32 of Set 11 : goma
# Processing Record 33 of Set 11 : poum
# City not found. Skipping...
# Processing Record 34 of Set 11 : skagen
# Processing Record 35 of Set 11 : dawan

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create a dataframe from prior steps
weather_data = pd.DataFrame({
    "City" : city_list,
    "Lat" : lats_list,
    "Lng" : lngs_list,
    "Max Temp" : temp_max_list,
    "Humidity" : humidity_list,
    "Clouds" : cloud_list,
    "Wind Speed" : wind_speed_list,
    "Country" : country_list,
    "Date" : date_list    
})

#Count weather data
weather_data.count()
# Out:
# City          545
# Lat           545
# Lng           545
# Max Temp      545
# Humidity      545
# Clouds        545
# Wind Speed    545
# Country       545
# Date          545
# dtype: int64

# %%
#Count weather data
weather_data.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Clouds  Wind Speed  \
# 0        Camocim  -2.9022  -40.8411     81.72        81     100        9.69
# 1        Iqaluit  63.7506  -68.5145    -11.00        64      75        2.17
# 2      Tuatapere -46.1333  167.6833     43.00        90       4        3.42
# 3    Port Alfred -33.5906   26.8910     73.26        81      68       14.90
# 4  San Cristobal   7.7669  -72.2250     75.20       100      75        4.36
#
#   Country        Date
# 0      BR  1615994063
# 1      CA  1615993901
# 2      NZ  1615994064
# 3      ZA  1615994064
# 4      VE  1615994064

# %%
#Save weather data to a cities csv file
weather_data.to_csv("../output_data/cities.csv", index=False)

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#check if there are any cities with >100% humidity
test_stats = weather_data["Humidity (%)"].describe(include = "all")
print("Max humidity is 100%. No values over 100% in the data")
test_stats
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Humidity (%)'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-0ccc3eb36553> in <module>
#       1 #check if there are any cities with >100% humidity
# ----> 2 test_stats = weather_data["Humidity (%)"].describe(include = "all")
#       3 print("Max humidity is 100%. No values over 100% in the data")
#       4 test_stats
#       5
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'Humidity (%)'

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Max Temperature (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Max Temperature.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Humidity"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Humidity (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%))")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Humidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Clouds"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Cloudiness (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%))")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Cloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], color = "steelblue", edgecolor = "black")

plt.title("City Latitude vs. Wind Speed (06/18/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (%))")
plt.grid(True)
plt.savefig("../Images/City Latitude vs Wind Speed.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
L=0
Northern = weather_data.query(f"Lat >= {L}")
Southern = weather_data.query(f"Lat <= {L}")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values=Northern['Lat']
y_values=Northern['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,270),fontsize=10,color="red")
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
plt.title('Latitude vs Max Temp (Northern Hemisphere)')
plt.style.use("classic")
R2="R^2="+str(round(rvalue,4))
plt.annotate(R2,(0,260),fontsize=10,color="red")
print(f"The r-value is: {rvalue}")
plt.savefig("Latitude vs Max Temp (Northern Hemisphere).png")
plt.show()
# Out:
# The r-value is: -0.8820350430437222

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values=Southern['Lat']
y_values=Southern['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,280),fontsize=10,color="red")
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
plt.title('Latitude vs Max Temp (Southern Hemisphere)')
plt.style.use("classic")
R2="r-value="+str(round(rvalue,4))
plt.annotate(R2,(-30,275),fontsize=10,color="red")
print(f"The r-value is: {rvalue}")
plt.savefig("Latitude vs Max Temp (Southern Hemisphere).png")
plt.show()
# Out:
# The r-value is: 0.7105838331856378

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values=Northern['Lat']
y_values=Northern['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(60,20),fontsize=10,color="red")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title('Latitude vs Humidity (Northern Hemisphere)')
plt.style.use("classic")
R2="r-value="+str(round(rvalue,4))
plt.annotate(R2,(65,15),fontsize=10,color="red")
print(f"The r-valueis: {rvalue}")
plt.savefig("Latitude vs Humidity (Northern Hemisphere).png")
plt.show()
# Out:
# The r-valueis: 0.33229820679395705

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values=Southern['Lat']
y_values=Southern['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,30),fontsize=10,color="red")
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.title('Latitude vs Humidity (Southern Hemisphere)')
plt.style.use("classic")
R2="r-value="+str(round(rvalue,4))
plt.annotate(R2,(-50,20),fontsize=10,color="red")
print(f"The r-value is: {rvalue}")
plt.savefig("Latitude vs Humidity (Southern Hemisphere).png")
plt.show()
# Out:
# The r-value is: 0.031218721571440428

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values=Northern['Lat']
y_values=Northern['Clouds']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-15),fontsize=10,color="red")
plt.ylabel('Clouds (%)')
plt.xlabel('Latitude')
plt.title('Latitude vs Cloudiness (Northern Hemisphere)')
plt.style.use("classic")
R2="r-value="+str(round(rvalue,4))
plt.annotate(R2,(60,-15),fontsize=10,color="red")
print(f"The r-value is: {rvalue}")
plt.savefig("Latitude vs Cloudiness (Northern Hemisphere).png")
plt.show()
# Out:
# The r-value is: 0.1251978203539479

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values=Southern['Lat']
y_values=Southern['Clouds']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,50),fontsize=10,color="red")
plt.ylabel('Max Temp')
plt.xlabel('Latitude')
plt.title('Latitude vs Cloudiness (Southern Hemisphere)')
plt.style.use("classic")
R2="r-value="+str(round(rvalue,4))
plt.annotate(R2,(-55,20),fontsize=10,color="red")
print(f"The r-value is: {rvalue}")
plt.savefig("Latitude vs Cloudiness (Southern Hemisphere).png")
plt.show()
# Out:
# The r-value is: 0.386294955808963

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values=Northern['Lat']
y_values=Northern['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,20),fontsize=10,color="red")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title('Latitude vs Wind Speed (Northern Hemisphere)')
plt.style.use("classic")
R2="r-value="+str(round(rvalue,4))
plt.annotate(R2,(0,18),fontsize=10,color="red")
print(f"The r-value is: {rvalue}")
plt.savefig("Latitude vs Wind Speed (Northern Hemisphere).png")
plt.show()
# Out:
# The r-value is: 0.10421544393456049

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values=Southern['Lat']
y_values=Southern['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-25,12),fontsize=10,color="red")
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.title('Latitude vs Wind Speed (Southern Hemisphere)')
plt.style.use("classic")
R2="r-value="+str(round(rvalue,4))
plt.annotate(R2,(-25,11),fontsize=10,color="red")
print(f"The r-value is: {rvalue}")
plt.savefig("Latitude vs Wind Speed (Southern Hemisphere).png")
plt.show()
# Out:
# The r-value is: -0.33325369990907583
